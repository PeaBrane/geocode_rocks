# %%
import pandas
import numpy as np

from urllib import request
from bs4 import BeautifulSoup

import re
from tqdm import tqdm

# %%
df = pandas.read_csv('bc_ropes.csv')

# %%
df
# Out:
#                            Route  \
# 0                      Star Chek
# 1                     [Redacted]
# 2             Local Boys Do Good
# 3              Pleasant Pheasant
# 4    Octopus Garden in the Shade
# ..                           ...
# 995                    Heat Wave
# 996                  Joan of Arc
# 997                       Sunset
# 998                     Restless
# 999       Mantel Health Problems
#
#                                               Location  \
# 0    Galaxy Buttress > The Gorge > Sea to Sky (Squa...
# 1    Forgotten Wall > Chek > Sea to Sky (Squamish t...
# 2    Shannon Falls Wall > Shannon Falls > Squamish ...
# 3    Petrifying Wall > Murrin Park > Squamish > Bri...
# 4    Octopus Garden > The Smoke Bluffs > Squamish >...
# ..                                                 ...
# 995  Raven Crag > CIC slabs > Nelson > Kootenays We...
# 996  KeTaMux > Castlegar > Kootenays West > British...
# 997  Creekside Wall > Cougar Canyon > Okanagan > Br...
# ...
