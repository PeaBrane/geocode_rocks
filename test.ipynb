# %%
import os
import pandas
import numpy as np

from urllib import request
from bs4 import BeautifulSoup

import re
from tqdm import tqdm

# %%
response = request.urlopen('https://www.mountainproject.com/route/106048290/false-hueco-traverse')
soup = BeautifulSoup(response.read(), 'html.parser')
images = soup.find_all('img')

imgdata = []
for img in images:
    try:
        imgdata.append(img['src'])
    except:
        continue

# %%
imgdata
# Out:
# ['/img/icons/closeX-lightBg.svg',
#  '/img/arrows/nextGray.svg',
#  '/img/social/white-facebook.svg',
#  '/img/climb/logoHexInvert.svg',
#  '/img/hamburgerIcon.svg',
#  '/img/climb/logoHex2.svg',
#  '/img/apple.png',
#  '/img/android.png',
#  '/img/arrowRightBlack.svg',
#  '/img/arrowRightBlack.svg',
#  '/img/arrowRightBlack.svg',
#  '/img/arrowRightBlack.svg',
#  '/img/arrowRightBlack.svg',
#  '/img/appleBlack.svg',
#  '/img/androidBlack.svg',
#  '/img/arrowRightBlack.svg',
#  '/img/icons/closeX-lightBg.svg',
#  '/img/climb/appIcon.svg',
#  '/img/partners/af-black.png',
#  '/img/downArrowBlack.svg',
#  '/img/downArrowBlack.svg',
#  '/img/icons/edit_climb.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/downArrowBlack.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlueHalf.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlueHalf.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlueHalf.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlueHalf.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlueHalf.svg',
#  '/img/stars/starBlue.svg',
#  '/img/stars/starBlue.svg',
#  '/img/clear.gif',
#  '/img/clear.gif',
#  '/img/clear.gif',
#  '/img/clear.gif',
#  '/img/clear.gif',
#  '/img/icons/trash.svg',
#  '/img/camera.svg',
#  '/img/camera.svg',
#  '/img/camera.svg',
#  '/img/camera.svg',
#  '/img/camera.svg',
#  '/img/camera.svg',
#  '/img/icons/edit_climb.svg',
#  '/img/icons/edit_climb.svg',
#  '/img/icons/edit_climb.svg',
#  '/img/downArrowBlack.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRedHalf.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRedHalf.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/stars/starRed.svg',
#  '/img/downArrowBlack.svg',
#  '/img/waitWhite.gif',
#  '/img/icons/closeX-darkBg.svg']
